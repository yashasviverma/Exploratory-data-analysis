# %% [markdown]
# ## YASHASVI VERMA

# %% [markdown]
# ### Exploratory data analysis project

# %% [markdown]
# Data Cleaning and EDA using the IMDB movies dataset

# %% [markdown]
# Importing python libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('C:\Datasets\movies.csv')

# %% [markdown]
# # Cleaning the data

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# budget                     0
# title                      0
# status                     0
# spoken_languages           0
# revenue                    0
# production_countries       0
# vote_average               0
# popularity                 0
# production_companies       0
# original_title             0
# original_language          0
# keywords                   0
# id                         0
# genres                     0
# vote_count                 0
# release_date               1
# runtime                    2
# overview                   3
# tagline                  844
# homepage                3091
# dtype: int64

# %%
df = df.drop(['homepage','tagline','overview'], axis=1)

# %%
df.head(2)
# Out:
#       budget                                             genres     id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# 1  Pirates of the Caribbean: At World's End  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# ...

# %%
print(df[df["release_date"].isnull()])
# Out:
#       budget genres      id keywords original_language  \
# 4553       0     []  380097       []                en
#
#                   original_title  popularity production_companies  \
# 4553  America Is Still the Place         0.0                   []
#
#      production_countries release_date  revenue  runtime spoken_languages  \
# 4553                   []          NaN        0      0.0               []
#
#         status                       title  vote_average  vote_count
# 4553  Released  America Is Still the Place           0.0           0

# %%
df = df[df['release_date'].notnull()]

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# runtime                 2
# vote_count              0
# production_companies    0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# popularity              0
# production_countries    0
# vote_average            0
# release_date            0
# revenue                 0
# spoken_languages        0
# status                  0
# title                   0
# budget                  0
# dtype: int64

# %%
df.groupby('runtime').runtime.count()
# Out:
# runtime
# 0.0      34
# 14.0      1
# 25.0      1
# 41.0      1
# 42.0      1
#          ..
# 242.0     1
# 248.0     1
# 254.0     1
# 276.0     1
# 338.0     1
# Name: runtime, Length: 156, dtype: int64

# %%
df.runtime.describe()
# Out:
# count    4800.000000
# mean      106.898125
# std        22.561593
# min         0.000000
# 25%        94.000000
# 50%       103.000000
# 75%       118.000000
# max       338.000000
# Name: runtime, dtype: float64

# %%
df.runtime = df.runtime.fillna(106.8)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# vote_count              0
# production_companies    0
# genres                  0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# popularity              0
# production_countries    0
# vote_average            0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# title                   0
# budget                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4802
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4802 non-null   int64
#  1   genres                4802 non-null   object
#  2   id                    4802 non-null   int64
#  3   keywords              4802 non-null   object
#  4   original_language     4802 non-null   object
#  5   original_title        4802 non-null   object
#  6   popularity            4802 non-null   float64
#  7   production_companies  4802 non-null   object
#  8   production_countries  4802 non-null   object
#  9   release_date          4802 non-null   object
#  10  revenue               4802 non-null   int64
#  11  runtime               4802 non-null   float64
#  12  spoken_languages      4802 non-null   object
#  13  status                4802 non-null   object
#  14  title                 4802 non-null   object
# ...

# %% [markdown]
# # 1) Which are the movies with the third-lowest and third-highest budget?

# %%
a = df.sort_values(by=['budget'])

# %%
a
# Out:
#          budget                                             genres      id  \
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
# 3582          0                      [{"id": 18, "name": "Drama"}]   15660
# 3585          0                      [{"id": 18, "name": "Drama"}]   19848
# 3587          0  [{"id": 18, "name": "Drama"}, {"id": 53, "name...  235271
# 1261          0                     [{"id": 35, "name": "Comedy"}]   11025
# ...         ...                                                ...     ...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    1452
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   99861
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 17    380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...    1865
#
# ...

# %%
a[2:3].original_title
# Out:
# 3585    The Players Club
# Name: original_title, dtype: object

# %%
a[-3:-2].original_title
# Out:
# 7    Avengers: Age of Ultron
# Name: original_title, dtype: object

# %% [markdown]
# ANS : Movie with the third-lowest budget is "The Players Club"
# Movie with third-highest budget is "Avengers: Age of Ultron"

# %% [markdown]
# # 2) What is the average number of words in movie titles between the years 2000-2005?

# %%
df.head(2)
# Out:
#       budget                                             genres     id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# 1  Pirates of the Caribbean: At World's End  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# ...

# %%
df.original_title
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: original_title, Length: 4802, dtype: object

# %%
start_date = "2000-01-01"
end_date = "2005-12-31"

# %%
a = df['release_date'] >= start_date

# %%
b = df['release_date'] <= end_date

# %%
between_2000_5 = a & b

# %%
filter_data = df.loc[between_2000_5]

# %%
new_data = filter_data

# %%
new_data
# Out:
#          budget                                             genres      id  \
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...     254
# 30    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...     558
# 63    180000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...     411
# 90    165000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...    5255
# 93    200000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...     296
# ...         ...                                                ...     ...
# 4790          0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...   13898
# 4793          0                      [{"id": 18, "name": "Drama"}]  182291
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...   14337
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...   67238
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
new_data.original_title
# Out:
# 24                                              King Kong
# 30                                           Spider-Man 2
# 63      The Chronicles of Narnia: The Lion, the Witch ...
# 90                                      The Polar Express
# 93                     Terminator 3: Rise of the Machines
#                               ...
# 4790                                                دایره
# 4793                                       On The Downlow
# 4796                                               Primer
# 4797                                               Cavite
# 4802                                    My Date with Drew
# Name: original_title, Length: 1142, dtype: object

# %%
count = new_data['original_title'].str.split().str.len()

# %%
count.sort_index(inplace=False)
# Out:
# 24       2
# 30       2
# 63      11
# 90       3
# 93       6
#         ..
# 4790     1
# 4793     3
# 4796     1
# 4797     1
# 4802     4
# Name: original_title, Length: 1142, dtype: int64

# %%
count.mean()
# Out:
# 2.7425569176882663

# %% [markdown]
# ANS : The average number of words in movie titles between the years 2000-2005 are *2.7425569176882663*

# %% [markdown]
# # 4) Which are the movies with the most and least earned revenue?

# %%
df.loc[df['revenue'].idxmax()]
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# popularity                                                        150.438
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# runtime                                                               162
# spoken_languages        [{"iso_639_1": "en", "name": "English"}, {"iso...
# ...

# %%
maximum = df.loc[df['revenue'].idxmax()].original_title

# %%
maximum
# Out:
# 'Avatar'

# %%
df.loc[df['revenue'].idxmin()]
# Out:
# budget                                                           27000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# id                                                                  79698
# keywords                                                               []
# original_language                                                      en
# original_title                                                 The Lovers
# popularity                                                        2.41853
# production_companies    [{"name": "Corsan", "id": 7299}, {"name": "Bli...
# production_countries    [{"iso_3166_1": "AU", "name": "Australia"}, {"...
# release_date                                                   2015-02-13
# revenue                                                                 0
# runtime                                                               109
# spoken_languages                 [{"iso_639_1": "en", "name": "English"}]
# ...

# %%
minimun = df.loc[df['revenue'].idxmin()].original_title

# %%
minimun
# Out:
# 'The Lovers'

# %% [markdown]
# ANS : Movie with the most earned revenue is 'Avatar' and
# Movie with the least earned revenue is 'The Lovers'

# %% [markdown]
# # 5) What is the average runtime of movies in the year 2006?

# %%
start_date = "2006-01-01"
end_date = "2007-01-01"

# %%
start_d = df['release_date'] >= start_date

# %%
end_d = df['release_date'] <= end_date

# %%
dates_bet = start_d & end_d

# %%
filter_d = df.loc[dates_bet]

# %%
filter_d
# Out:
#          budget                                             genres      id  \
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    1452
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...      58
# 33    210000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...   36668
# 104   160000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...     503
# 139   150000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...     956
# ...         ...                                                ...     ...
# 4612     300000                      [{"id": 18, "name": "Drama"}]   26518
# 4662          0                     [{"id": 35, "name": "Comedy"}]   40963
# 4722     100000                      [{"id": 18, "name": "Drama"}]   18925
# 4754          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...   84659
# 4791         13                     [{"id": 27, "name": "Horror"}]  157185
#
# ...

# %%
new_d = filter_d

# %%
new_d.runtime.describe()
# Out:
# count    243.000000
# mean     104.897119
# std       22.223362
# min        0.000000
# 25%       91.500000
# 50%      103.000000
# 75%      117.000000
# max      193.000000
# Name: runtime, dtype: float64

# %%
mean_d = new_d["runtime"].mean()

# %%
mean_d
# Out:
# 104.89711934156378

# %% [markdown]
# ANS : The average runtime of movies in the year 2006 is *104.89711934156378*
